# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico-ASL/Challenge-Telecomx2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-070b8cab-5c72-4baf-af68-b5f9c7260297" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-070b8cab-5c72-4baf-af68-b5f9c7260297">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("telecomx_limpio.csv")

df.head()
# Out:
#    customerID  Churn  Genero  AdultoMayor TienePareja Dependientes  \
# 0  0002-ORFBO    0.0  Female            0         Yes          Yes
# 1  0003-MKNFE    0.0    Male            0          No           No
# 2  0004-TLHLJ    1.0    Male            0          No           No
# 3  0011-IGKFF    1.0    Male            1         Yes           No
# 4  0013-EXCHZ    1.0  Female            1         Yes           No
#
#    MesesCliente  ServicioTelefono MultiplesLineas ServicioInternet  ...  \
# 0             9                 1              No              DSL  ...
# 1             9                 1             Yes              DSL  ...
# 2             4                 1              No      Fiber optic  ...
# 3            13                 1              No      Fiber optic  ...
# 4             3                 1              No      Fiber optic  ...
#
#   internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# ...

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
X.head()
# Out:
#    customerID  Genero  AdultoMayor TienePareja Dependientes  MesesCliente  \
# 0  0002-ORFBO  Female            0         Yes          Yes             9
# 1  0003-MKNFE    Male            0          No           No             9
# 2  0004-TLHLJ    Male            0          No           No             4
# 3  0011-IGKFF    Male            1         Yes           No            13
# 4  0013-EXCHZ  Female            1         Yes           No             3
#
#    ServicioTelefono MultiplesLineas ServicioInternet internet.OnlineSecurity  \
# 0                 1              No              DSL                      No
# 1                 1             Yes              DSL                      No
# 2                 1              No      Fiber optic                      No
# 3                 1              No      Fiber optic                      No
# 4                 1              No      Fiber optic                      No
#
# ...

# %%
y.head()
# Out:
# 0    0.0
# 1    0.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Churn, dtype: float64

# %%
X.select_dtypes(include=['object']).columns
# Out:
# Index(['customerID', 'Genero', 'TienePareja', 'Dependientes',
#        'MultiplesLineas', 'ServicioInternet', 'internet.OnlineSecurity',
#        'internet.OnlineBackup', 'internet.DeviceProtection',
#        'internet.TechSupport', 'internet.StreamingTV',
#        'internet.StreamingMovies', 'TipoContrato', 'MetodoPago'],
#       dtype='object')

# %%
X.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['AdultoMayor', 'MesesCliente', 'ServicioTelefono', 'FacturacionDigital',
#        'CargoMensual', 'CargoTotal', 'Cuentas_Diarias'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'Genero', 'AdultoMayor', 'TienePareja',
#        'Dependientes', 'MesesCliente', 'ServicioTelefono', 'MultiplesLineas',
#        'ServicioInternet', 'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'TipoContrato',
#        'FacturacionDigital', 'MetodoPago', 'CargoMensual', 'CargoTotal',
#        'Cuentas_Diarias'],
#       dtype='object')

# %%
df = df.drop(columns=['customerID'])

# %%
df.columns
# Out:
# Index(['Churn', 'Genero', 'AdultoMayor', 'TienePareja', 'Dependientes',
#        'MesesCliente', 'ServicioTelefono', 'MultiplesLineas',
#        'ServicioInternet', 'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'TipoContrato',
#        'FacturacionDigital', 'MetodoPago', 'CargoMensual', 'CargoTotal',
#        'Cuentas_Diarias'],
#       dtype='object')

# %%
df.head()
# Out:
#    Churn  Genero  AdultoMayor TienePareja Dependientes  MesesCliente  \
# 0    0.0  Female            0         Yes          Yes             9
# 1    0.0    Male            0          No           No             9
# 2    1.0    Male            0          No           No             4
# 3    1.0    Male            1         Yes           No            13
# 4    1.0  Female            1         Yes           No             3
#
#    ServicioTelefono MultiplesLineas ServicioInternet internet.OnlineSecurity  \
# 0                 1              No              DSL                      No
# 1                 1             Yes              DSL                      No
# 2                 1              No      Fiber optic                      No
# 3                 1              No      Fiber optic                      No
# 4                 1              No      Fiber optic                      No
#
#    ... internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# ...

# %%
categoricas = df.select_dtypes(include=['object']).columns

print(categoricas)
# Out:
# Index(['Genero', 'TienePareja', 'Dependientes', 'MultiplesLineas',
#        'ServicioInternet', 'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'TipoContrato',
#        'MetodoPago'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(
    df,
    columns=[
        'Genero',
        'TienePareja',
        'Dependientes',
        'MultiplesLineas',
        'ServicioInternet',
        'internet.OnlineSecurity',
        'internet.OnlineBackup',
        'internet.DeviceProtection',
        'internet.TechSupport',
        'internet.StreamingTV',
        'internet.StreamingMovies',
        'TipoContrato',
        'MetodoPago'
    ],
    drop_first=True
)

# %%
df_encoded.head()
# Out:
#    Churn  AdultoMayor  MesesCliente  ServicioTelefono  FacturacionDigital  \
# 0    0.0            0             9                 1                   1
# 1    0.0            0             9                 1                   0
# 2    1.0            0             4                 1                   1
# 3    1.0            1            13                 1                   1
# 4    1.0            1             3                 1                   1
#
#    CargoMensual  CargoTotal  Cuentas_Diarias  Genero_Male  TienePareja_Yes  \
# 0          65.6      593.30         2.186667        False             True
# 1          59.9      542.40         1.996667         True            False
# 2          73.9      280.85         2.463333         True            False
# 3          98.0     1237.85         3.266667         True             True
# 4          83.9      267.40         2.796667        False             True
#
# ...

# %%
df_encoded.columns
# Out:
# Index(['Churn', 'AdultoMayor', 'MesesCliente', 'ServicioTelefono',
#        'FacturacionDigital', 'CargoMensual', 'CargoTotal', 'Cuentas_Diarias',
#        'Genero_Male', 'TienePareja_Yes', 'Dependientes_Yes',
#        'MultiplesLineas_No phone service', 'MultiplesLineas_Yes',
#        'ServicioInternet_Fiber optic', 'ServicioInternet_No',
#        'internet.OnlineSecurity_No internet service',
#        'internet.OnlineSecurity_Yes',
#        'internet.OnlineBackup_No internet service',
#        'internet.OnlineBackup_Yes',
#        'internet.DeviceProtection_No internet service',
#        'internet.DeviceProtection_Yes',
#        'internet.TechSupport_No internet service', 'internet.TechSupport_Yes',
#        'internet.StreamingTV_No internet service', 'internet.StreamingTV_Yes',
#        'internet.StreamingMovies_No internet service',
#        'internet.StreamingMovies_Yes', 'TipoContrato_One year',
#        'TipoContrato_Two year', 'MetodoPago_Credit card (automatic)',
# ...

# %%
df_encoded.shape
# Out:
# (7267, 32)

# %%
X = df_encoded.drop('Churn', axis=1)
y = df_encoded['Churn']

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0.0    5174
# 1.0    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# 0.0    73.463013
# 1.0    26.536987
# Name: proportion, dtype: float64

# %%
proporcion = df['Churn'].value_counts(normalize=True) * 100

print(f"Clientes activos: {proporcion[0]:.2f}%")
print(f"Clientes que cancelaron: {proporcion[1]:.2f}%")
# Out:
# Clientes activos: 73.46%
# Clientes que cancelaron: 26.54%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Churn', data=df)
plt.title('Distribución de cancelación de clientes')
plt.xlabel('Cancelación (0 = No, 1 = Sí)')
plt.ylabel('Cantidad de clientes')
plt.show()

# %%
X = df_encoded.drop('Churn', axis=1)
y = df_encoded['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_189/3907347504.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(
#       4     X, y,
#       5     test_size=0.3,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
# ...

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_189/2246605163.py in <cell line: 0>()
#       3 ros = RandomOverSampler(random_state=42)
#       4
# ----> 5 X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
correlacion = df_encoded.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(correlacion, cmap='coolwarm', center=0)
plt.title("Matriz de correlación de variables")
plt.show()

# %%
correlacion_churn = df_encoded.corr()['Churn'].sort_values(ascending=False)

correlacion_churn
# Out:
# Churn                                            1.000000
# ServicioInternet_Fiber optic                     0.308020
# MetodoPago_Electronic check                      0.301919
# CargoMensual                                     0.193356
# Cuentas_Diarias                                  0.193356
# FacturacionDigital                               0.191825
# AdultoMayor                                      0.150889
# internet.StreamingTV_Yes                         0.063228
# internet.StreamingMovies_Yes                     0.061382
# MultiplesLineas_Yes                              0.040102
# ServicioTelefono                                 0.011942
# Genero_Male                                     -0.008612
# MultiplesLineas_No phone service                -0.011942
# internet.DeviceProtection_Yes                   -0.066160
# internet.OnlineBackup_Yes                       -0.082255
# MetodoPago_Mailed check                         -0.091683
# ...

# %%
top_correlaciones = correlacion_churn.drop('Churn').head(10)

plt.figure(figsize=(8,5))
sns.barplot(x=top_correlaciones.values, y=top_correlaciones.index)
plt.title("Variables más correlacionadas con Churn")
plt.xlabel("Correlación")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.boxplot(x='Churn', y='MesesCliente', data=df)

plt.title('Tiempo de contrato vs Cancelación')
plt.xlabel('Cancelación (0 = No, 1 = Sí)')
plt.ylabel('Tiempo como cliente (meses)')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x='MesesCliente',
    y='CargoTotal',
    hue='Churn',
    data=df,
    alpha=0.6
)

plt.title('Relación entre tiempo de contrato y gasto total')
plt.xlabel('Tiempo como cliente (meses)')
plt.ylabel('Gasto total')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn', y='CargoMensual', data=df)

plt.title('Gasto mensual vs Cancelación')
plt.xlabel('Cancelación')
plt.ylabel('Gasto mensual')
plt.show()

# %%
X = df_encoded.drop('Churn', axis=1)
y = df_encoded['Churn']

# %%
df['Churn'].isna().sum()
# Out:
# np.int64(224)

# %%
df[df['Churn'].isna()]
# Out:
#       Churn  Genero  AdultoMayor TienePareja Dependientes  MesesCliente  \
# 30      NaN  Female            0          No           No            11
# 75      NaN    Male            0          No           No            71
# 96      NaN    Male            0          No           No            29
# 98      NaN  Female            1          No           No             5
# 175     NaN    Male            1         Yes           No            65
# ...     ...     ...          ...         ...          ...           ...
# 7158    NaN  Female            0          No           No            14
# 7180    NaN  Female            0         Yes           No            49
# 7211    NaN    Male            0          No           No             9
# 7239    NaN  Female            0         Yes          Yes            67
# 7247    NaN  Female            0         Yes          Yes            31
#
#       ServicioTelefono   MultiplesLineas ServicioInternet  \
# ...

# %%
df = df.dropna(subset=['Churn'])

# %%
df['Churn'].isna().sum()
# Out:
# np.int64(0)

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
X = df_encoded.drop('Churn', axis=1)
y = df_encoded['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4930, 31)
# (2113, 31)
# (4930,)
# (2113,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

modelo_lr = LogisticRegression(max_iter=1000)

modelo_lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred_lr = modelo_lr.predict(X_test_scaled)

# %%
from sklearn.ensemble import RandomForestClassifier

modelo_rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

modelo_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred_rf = modelo_rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
print("Regresión Logística")

print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Precision:", precision_score(y_test, y_pred_lr))
print("Recall:", recall_score(y_test, y_pred_lr))
print("F1-score:", f1_score(y_test, y_pred_lr))
# Out:
# Regresión Logística
# Accuracy: 0.7983909133932797
# Precision: 0.6415094339622641
# Recall: 0.5454545454545454
# F1-score: 0.5895953757225434

# %%
print("Random Forest")

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall:", recall_score(y_test, y_pred_rf))
print("F1-score:", f1_score(y_test, y_pred_rf))
# Out:
# Random Forest
# Accuracy: 0.7841930903928065
# Precision: 0.6148796498905909
# Recall: 0.5008912655971479
# F1-score: 0.5520628683693517

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_rf)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de confusión - Random Forest")

plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("=== Regresión Logística ===")

print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Precision:", precision_score(y_test, y_pred_lr))
print("Recall:", recall_score(y_test, y_pred_lr))
print("F1-score:", f1_score(y_test, y_pred_lr))

print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred_lr))
# Out:
# === Regresión Logística ===
# Accuracy: 0.7983909133932797
# Precision: 0.6415094339622641
# Recall: 0.5454545454545454
# F1-score: 0.5895953757225434
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.89      0.87      1552
#          1.0       0.64      0.55      0.59       561
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.72      0.73      2113
# weighted avg       0.79      0.80      0.79      2113

# %%
cm_lr = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(6,4))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')

plt.title("Matriz de confusión - Regresión Logística")
plt.xlabel("Predicción")
plt.ylabel("Valor real")

plt.show()

# %%
print("=== Random Forest ===")

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall:", recall_score(y_test, y_pred_rf))
print("F1-score:", f1_score(y_test, y_pred_rf))

print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred_rf))
# Out:
# === Random Forest ===
# Accuracy: 0.7841930903928065
# Precision: 0.6148796498905909
# Recall: 0.5008912655971479
# F1-score: 0.5520628683693517
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.89      0.86      1552
#          1.0       0.61      0.50      0.55       561
#
#     accuracy                           0.78      2113
#    macro avg       0.72      0.69      0.70      2113
# weighted avg       0.77      0.78      0.78      2113

# %%
import pandas as pd

resultados = pd.DataFrame({
    "Modelo": ["Regresión Logística", "Random Forest"],
    "Accuracy": [
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_rf)
    ],
    "Precision": [
        precision_score(y_test, y_pred_lr),
        precision_score(y_test, y_pred_rf)
    ],
    "Recall": [
        recall_score(y_test, y_pred_lr),
        recall_score(y_test, y_pred_rf)
    ],
    "F1-score": [
        f1_score(y_test, y_pred_lr),
        f1_score(y_test, y_pred_rf)
    ]
})

resultados
# Out:
#                 Modelo  Accuracy  Precision    Recall  F1-score
# 0  Regresión Logística  0.798391   0.641509  0.545455  0.589595
# 1        Random Forest  0.784193   0.614880  0.500891  0.552063

# %%
import pandas as pd

coeficientes = pd.DataFrame({
    "Variable": X.columns,
    "Coeficiente": modelo_lr.coef_[0]
})

coeficientes = coeficientes.sort_values(by="Coeficiente", ascending=False)

coeficientes.head(10)
# Out:
#                             Variable  Coeficiente
# 5                         CargoTotal     0.706182
# 12      ServicioInternet_Fiber optic     0.615297
# 3                 FacturacionDigital     0.202033
# 23          internet.StreamingTV_Yes     0.193647
# 11               MultiplesLineas_Yes     0.175889
# 25      internet.StreamingMovies_Yes     0.173362
# 29       MetodoPago_Electronic check     0.173207
# 0                        AdultoMayor     0.062378
# 19     internet.DeviceProtection_Yes     0.037067
# 10  MultiplesLineas_No phone service     0.026847

# %%
coeficientes.head(10)
# Out:
#                             Variable  Coeficiente
# 5                         CargoTotal     0.706182
# 12      ServicioInternet_Fiber optic     0.615297
# 3                 FacturacionDigital     0.202033
# 23          internet.StreamingTV_Yes     0.193647
# 11               MultiplesLineas_Yes     0.175889
# 25      internet.StreamingMovies_Yes     0.173362
# 29       MetodoPago_Electronic check     0.173207
# 0                        AdultoMayor     0.062378
# 19     internet.DeviceProtection_Yes     0.037067
# 10  MultiplesLineas_No phone service     0.026847

# %%
coeficientes.tail(10)
# Out:
#                                          Variable  Coeficiente
# 20       internet.TechSupport_No internet service    -0.076550
# 18  internet.DeviceProtection_No internet service    -0.076550
# 9                                Dependientes_Yes    -0.094594
# 15                    internet.OnlineSecurity_Yes    -0.095681
# 21                       internet.TechSupport_Yes    -0.148349
# 26                          TipoContrato_One year    -0.302788
# 4                                    CargoMensual    -0.313681
# 6                                 Cuentas_Diarias    -0.313681
# 27                          TipoContrato_Two year    -0.564389
# 1                                    MesesCliente    -1.457422

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_coef = coeficientes.head(10)

plt.figure(figsize=(8,5))
sns.barplot(x="Coeficiente", y="Variable", data=top_coef)

plt.title("Variables que aumentan la cancelación (Regresión Logística)")
plt.show()

# %%
importancias = pd.DataFrame({
    "Variable": X.columns,
    "Importancia": modelo_rf.feature_importances_
})

importancias = importancias.sort_values(by="Importancia", ascending=False)

importancias.head(10)
# Out:
#                         Variable  Importancia
# 5                     CargoTotal     0.172383
# 1                   MesesCliente     0.155186
# 6                Cuentas_Diarias     0.127807
# 4                   CargoMensual     0.126261
# 29   MetodoPago_Electronic check     0.038485
# 12  ServicioInternet_Fiber optic     0.032624
# 27         TipoContrato_Two year     0.028663
# 7                    Genero_Male     0.025120
# 3             FacturacionDigital     0.024881
# 26         TipoContrato_One year     0.023101

# %%
top_importancias = importancias.head(10)

plt.figure(figsize=(8,5))
sns.barplot(x="Importancia", y="Variable", data=top_importancias)

plt.title("Variables más importantes - Random Forest")
plt.show()
